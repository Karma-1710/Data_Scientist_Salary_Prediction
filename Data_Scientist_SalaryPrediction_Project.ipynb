# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("glassdoor_jobs.csv")

# %% [markdown]
# # Information About DataSet

# %%
df.shape
# Out:
# (956, 15)

# %%
df
# Out:
#      Unnamed: 0                                          Job Title  \
# 0             0                                     Data Scientist
# 1             1                          Healthcare Data Scientist
# 2             2                                     Data Scientist
# 3             3                                     Data Scientist
# 4             4                                     Data Scientist
# ..          ...                                                ...
# 951         951                               Senior Data Engineer
# 952         952  Project Scientist - Auton Lab, Robotics Institute
# 953         953                               Data Science Manager
# 954         954                                      Data Engineer
# 955         955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Job Title', 'Salary Estimate', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0                  Job Title              Salary Estimate  \
# 0           0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1           1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2           2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3           3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4           4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# Job Title             object
# Salary Estimate       object
# Job Description       object
# Rating               float64
# Company Name          object
# Location              object
# Headquarters          object
# Size                  object
# Founded                int64
# Type of ownership     object
# Industry              object
# Sector                object
# Revenue               object
# Competitors           object
# dtype: object

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.describe()
# Out:
#            Rating      Founded
# count  956.000000   956.000000
# mean     3.601255  1774.605649
# std      1.067619   598.942517
# min     -1.000000    -1.000000
# 25%      3.300000  1937.000000
# 50%      3.800000  1992.000000
# 75%      4.200000  2008.000000
# max      5.000000  2019.000000

# %%
df.isnull().any()
# Out:
# Job Title            False
# Salary Estimate      False
# Job Description      False
# Rating               False
# Company Name         False
# Location             False
# Headquarters         False
# Size                 False
# Founded              False
# Type of ownership    False
# Industry             False
# Sector               False
# Revenue              False
# Competitors          False
# dtype: bool

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors'],
#       dtype='object')

# %%
# Removing the -1 values from the data set from Estimate Column
df = df[df['Salary Estimate'] != "-1"]
df.shape
# Out:
# (742, 14)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Spliting the () part from the Salary Estimate Column

# %%
test = lambda x: x.split("(")[0]
test("53𝐾−91K (Glassdoor est.)")
# Out:
# '53𝐾−91K '

# %%
salary = df['Salary Estimate'].apply(lambda x: x.split("(")[0])
salary
# Out:
# 0       $53K-$91K
# 1      $63K-$112K
# 2       $80K-$90K
# 3       $56K-$97K
# 4      $86K-$143K
#           ...
# 950    $58K-$111K
# 951    $72K-$133K
# 952     $56K-$91K
# 953    $95K-$160K
# 955    $61K-$126K
# Name: Salary Estimate, Length: 742, dtype: object

# %% [markdown]
# Removing the $ and K symbol from Salary

# %%
salary = salary.apply(lambda x: x.replace("$", "").replace("K", ""))
salary
# Out:
# 0       53-91
# 1      63-112
# 2       80-90
# 3       56-97
# 4      86-143
#         ...
# 950    58-111
# 951    72-133
# 952     56-91
# 953    95-160
# 955    61-126
# Name: Salary Estimate, Length: 742, dtype: object

# %%
len(salary.unique())
# Out:
# 416

# %%
# Checking for inconsistencies in the data:
salary.unique()[380:]
# Out:
# array(['84-153 ', '44-73 ', '40-87 ', '72-142 ', '74-137 ', '57-109 ',
#        '136-208 ', '171-272 ', '65-126 ', '118-228 ', '113-182 ',
#        '58-104 ', '58-108 ', '81-161 ', '115-220 ', '71-144 ', '32-57 ',
#        '79-136 ', '48-113 ', '27-47 Per Hour', '68-125 ', '39-67 ',
#        '71-135 ', '61-123 ', '87-141 ', '71-121 ', '72-121 ', '51-88 ',
#        '101-141 ', '79-127 ', '81-132 ',
#        'Employer Provided Salary:120-140', '65-113 ', '59-125 ',
#        '80-142 ', '62-113 '], dtype=object)

# %%
# Creating a Column for "Per Hour"
df["salary_per_hour"] = salary.apply(lambda x:1 if "per hour" in x.lower() else 0)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\473449065.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["salary_per_hour"] = salary.apply(lambda x:1 if "per hour" in x.lower() else 0)

# %%
df["salary_per_hour"].value_counts()
# Out:
# salary_per_hour
# 0    718
# 1     24
# Name: count, dtype: int64

# %%
df["emp_provided_salary"] = salary.apply(lambda x:1 if "employer provided salary" in x.lower() else 0)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\802210497.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["emp_provided_salary"] = salary.apply(lambda x:1 if "employer provided salary" in x.lower() else 0)

# %%
df["emp_provided_salary"].value_counts()
# Out:
# emp_provided_salary
# 0    725
# 1     17
# Name: count, dtype: int64

# %%
salary = salary.apply(lambda x: x.lower().replace("per hour", "").replace("employer provided salary:", "").replace(" ", ""))

# %%
salary.unique()[380:]
# Out:
# array(['84-153', '44-73', '40-87', '72-142', '74-137', '57-109',
#        '136-208', '171-272', '65-126', '118-228', '113-182', '58-104',
#        '58-108', '81-161', '115-220', '71-144', '32-57', '79-136',
#        '48-113', '27-47', '68-125', '39-67', '71-135', '61-123', '87-141',
#        '71-121', '72-121', '51-88', '101-141', '79-127', '81-132',
#        '120-140', '65-113', '59-125', '80-142', '62-113'], dtype=object)

# %%
df["min_salary"] = salary.apply(lambda x: int(x.split("-")[0]))
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1373495597.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["min_salary"] = salary.apply(lambda x: int(x.split("-")[0]))

# %%
df["min_salary"].tail()
# Out:
# 950    58
# 951    72
# 952    56
# 953    95
# 955    61
# Name: min_salary, dtype: int64

# %%
df["max_salary"] = salary.apply(lambda x: int(x.split("-")[1]))
df["max_salary"].tail()
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\15690981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["max_salary"] = salary.apply(lambda x: int(x.split("-")[1]))
# 950    111
# 951    133
# 952     91
# 953    160
# 955    126
# Name: max_salary, dtype: int64

# %% [markdown]
# ## Calculating the Average Salary

# %%
df["average_salary"] = (df["min_salary"] + df["max_salary"])/2
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\590206120.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["average_salary"] = (df["min_salary"] + df["max_salary"])/2

# %%
df
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                            Healthcare Data Scientist
# 2                                       Data Scientist
# 3                                       Data Scientist
# 4                                       Data Scientist
# ..                                                 ...
# 950           Sr Scientist, Immuno-Oncology - Oncology
# 951                               Senior Data Engineer
# 952  Project Scientist - Auton Lab, Robotics Institute
# 953                               Data Science Manager
# 955          Research Scientist – Security and Privacy
#
#                  Salary Estimate  \
# 0     $53K-$91K (Glassdoor est.)
# 1    $63K-$112K (Glassdoor est.)
# 2     $80K-$90K (Glassdoor est.)
# 3     $56K-$97K (Glassdoor est.)
# 4    $86K-$143K (Glassdoor est.)
# ..                           ...
# 950  $58K-$111K (Glassdoor est.)
# ...

# %%
df['min_salary'] = df.apply(lambda x: x['min_salary']*2 if x['salary_per_hour'] == 1 else x['min_salary'], axis=1)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\57064555.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['min_salary'] = df.apply(lambda x: x['min_salary']*2 if x['salary_per_hour'] == 1 else x['min_salary'], axis=1)

# %%
df['max_salary'] = df.apply(lambda x:x['max_salary']*2 if x['salary_per_hour'] == 1 else x['max_salary'], axis=1)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\276268478.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['max_salary'] = df.apply(lambda x:x['max_salary']*2 if x['salary_per_hour'] == 1 else x['max_salary'], axis=1)

# %%
df[df['salary_per_hour'] == 1][['salary_per_hour', 'min_salary', 'max_salary']]
# Out:
#      salary_per_hour  min_salary  max_salary
# 197                1          34          48
# 209                1          42          68
# 240                1          36          50
# 247                1          42          68
# 257                1          30          50
# 307                1          34          48
# 337                1          42          68
# 427                1          36          50
# 437                1          48          78
# 456                1          42          68
# 464                1          50          56
# 522                1          42          58
# 523                1          20          34
# 632                1          36          50
# 652                1          48          78
# 682                1          42          68
# 694                1          50          56
# 786                1          42          58
# 787                1          20          34
# 823                1          54          94
# ...

# %%
df.head(1)
# Out:
#         Job Title             Salary Estimate  \
# 0  Data Scientist  $53K-$91K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
#
#              Company Name         Location Headquarters  \
# 0  Tecolote Research\n3.8  Albuquerque, NM   Goleta, CA
#
#                     Size  Founded  Type of ownership             Industry  \
# 0  501 to 1000 employees     1973  Company - Private  Aerospace & Defense
#
#                 Sector                    Revenue Competitors  \
# 0  Aerospace & Defense  $50 to $100 million (USD)          -1
#
#    salary_per_hour  emp_provided_salary  min_salary  max_salary  \
# 0                0                    0          53          91
#
#    average_salary
# 0            72.0

# %% [markdown]
# ### Further Company Name data cleaning

# %%
df['Company Name'] = df['Company Name'].apply(lambda x: x.split('\n')[0])
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\2917893684.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Company Name'] = df['Company Name'].apply(lambda x: x.split('\n')[0])

# %%
df['Company Name'].head()
# Out:
# 0                        Tecolote Research
# 1    University of Maryland Medical System
# 2                                  KnowBe4
# 3                                     PNNL
# 4                       Affinity Solutions
# Name: Company Name, dtype: object

# %%
# Creating a job_state column
df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
df['job_state'].head()
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\2670954192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_state'] = df['Location'].apply(lambda x: x.split(',')[1])
# 0     NM
# 1     MD
# 2     FL
# 3     WA
# 4     NY
# Name: job_state, dtype: object

# %%
df['job_state'].unique()
# Out:
# array([' NM', ' MD', ' FL', ' WA', ' NY', ' TX', ' CA', ' VA', ' MA',
#        ' NJ', ' CO', ' IL', ' KY', ' OR', ' CT', ' MI', ' DC', ' OH',
#        ' AL', ' MO', ' PA', ' GA', ' IN', ' LA', ' WI', ' NC', ' AZ',
#        ' NE', ' MN', ' Los Angeles', ' UT', ' TN', ' DE', ' ID', ' RI',
#        ' IA', ' SC', ' KS'], dtype=object)

# %%
df['job_state'] = df['job_state'].apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df['job_state'].value_counts()[:5]
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\2923329246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_state'] = df['job_state'].apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
# job_state
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# Name: count, dtype: int64

# %%
df['job_state'].unique()
# Out:
# array(['NM', 'MD', 'FL', 'WA', 'NY', 'TX', 'CA', 'VA', 'MA', 'NJ', 'CO',
#        'IL', 'KY', 'OR', 'CT', 'MI', 'DC', 'OH', 'AL', 'MO', 'PA', 'GA',
#        'IN', 'LA', 'WI', 'NC', 'AZ', 'NE', 'MN', 'UT', 'TN', 'DE', 'ID',
#        'RI', 'IA', 'SC', 'KS'], dtype=object)

# %%
df.head(1)
# Out:
#         Job Title             Salary Estimate  \
# 0  Data Scientist  $53K-$91K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
#
#         Company Name         Location Headquarters                   Size  \
# 0  Tecolote Research  Albuquerque, NM   Goleta, CA  501 to 1000 employees
#
#    Founded  Type of ownership             Industry               Sector  \
# 0     1973  Company - Private  Aerospace & Defense  Aerospace & Defense
#
#                      Revenue Competitors  salary_per_hour  \
# 0  $50 to $100 million (USD)          -1                0
#
#    emp_provided_salary  min_salary  max_salary  average_salary job_state
# 0                    0          53          91            72.0        NM

# %% [markdown]
# ### Calculating the age of Companies

# %%
df['company_age'] = df['Founded'].apply(lambda x: x if x<1 else 2023-x)
df['company_age'].head()
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1203456934.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['company_age'] = df['Founded'].apply(lambda x: x if x<1 else 2023-x)
# 0    50
# 1    39
# 2    13
# 3    58
# 4    25
# Name: company_age, dtype: int64

# %%
df.head(1)
# Out:
#         Job Title             Salary Estimate  \
# 0  Data Scientist  $53K-$91K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
#
#         Company Name         Location Headquarters                   Size  \
# 0  Tecolote Research  Albuquerque, NM   Goleta, CA  501 to 1000 employees
#
#    Founded  Type of ownership  ...               Sector  \
# 0     1973  Company - Private  ...  Aerospace & Defense
#
#                      Revenue Competitors salary_per_hour  emp_provided_salary  \
# 0  $50 to $100 million (USD)          -1               0                    0
#
#    min_salary  max_salary  average_salary  job_state company_age
# 0          53          91            72.0         NM          50
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Cleaning the Job Description Column

# %%
df['python_job'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
df['r_job'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() else 0)
df['spark_job'] = df['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
df['aws_job'] = df['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)
df['excel_job'] = df["Job Description"].apply(lambda x: 1 if 'excel' in x.lower() else 0)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\79910838.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['python_job'] = df['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\79910838.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['r_job'] = df['Job Description'].apply(lambda x: 1 if 'r studio' in x.lower() else 0)
# ...

# %%
df.python_job.value_counts()
# Out:
# python_job
# 1    392
# 0    350
# Name: count, dtype: int64

# %%
df.r_job.value_counts()
# Out:
# r_job
# 0    741
# 1      1
# Name: count, dtype: int64

# %%
df.spark_job.value_counts()
# Out:
# spark_job
# 0    575
# 1    167
# Name: count, dtype: int64

# %%
df.aws_job.value_counts()
# Out:
# aws_job
# 0    566
# 1    176
# Name: count, dtype: int64

# %%
df.excel_job.value_counts()
# Out:
# excel_job
# 1    388
# 0    354
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# ...

# %% [markdown]
# ## Cleaning the Job Title Column

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else: 
        return 'na'
    
df['job_title_simplified'] = df['Job Title'].apply(title_simplifier)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1725639378.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_title_simplified'] = df['Job Title'].apply(title_simplifier)

# %%
df['job_title_simplified'].value_counts()
# Out:
# job_title_simplified
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# manager            22
# mle                22
# director           14
# Name: count, dtype: int64

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# ...

# %%
def seniority(title):
    if 'sr' in title.lower() or 'senior' in title.lower() or 'sr.' in title.lower() or 'lead' in title.lower() or 'head' in title.lower() or 'chief' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else: 
        return 'na'
    
df['job_seniority'] = df["Job Title"].apply(seniority)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\3123658296.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['job_seniority'] = df["Job Title"].apply(seniority)

# %%
df['job_seniority'].value_counts()
# Out:
# job_seniority
# na        545
# senior    195
# jr          2
# Name: count, dtype: int64

# %%
df.head(5)
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                             Company Name         Location    Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM      Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD   Baltimore, MD
# ...

# %%
df['Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
df['Competitors']
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1226180709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Competitors'] = df['Competitors'].apply(lambda x: len(x.split(',')) if x != '-1' else 0)
# 0      0
# 1      0
# 2      0
# 3      3
# 4      3
#       ..
# 950    3
# 951    3
# 952    0
# 953    0
# 955    0
# Name: Competitors, Length: 742, dtype: int64

# %%
df['Type of ownership'].value_counts()
# Out:
# Type of ownership
# Company - Private                 410
# Company - Public                  193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  3
# School / School District            2
# Unknown                             1
# -1                                  1
# Name: count, dtype: int64

# %%
def ownership_simplifier(text):
    if 'private' in text.lower(): 
        return 'Private'
    elif 'public' in text.lower():
        return 'Public'
    elif ('-1' in text.lower()) or ('unknown' in text.lower()):
        return 'Other Organization'
    else:
        return text
    
df['Type of ownership'] = df['Type of ownership'].apply(ownership_simplifier)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\3980578867.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Type of ownership'] = df['Type of ownership'].apply(ownership_simplifier)

# %%
df['Type of ownership'].value_counts()
# Out:
# Type of ownership
# Private                           410
# Public                            193
# Nonprofit Organization             55
# Subsidiary or Business Segment     34
# Government                         15
# Hospital                           15
# College / University               13
# Other Organization                  5
# School / School District            2
# Name: count, dtype: int64

# %%
df['Revenue'].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            203
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# -1                                    1
# Name: count, dtype: int64

# %%
def revenue_simplifier(text):
    if '-1' in text.lower():
        return 'Unknown / Non-Applicable'
    else:
        return text

df['Revenue'] = df['Revenue'].apply(revenue_simplifier)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1933429323.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Revenue'] = df['Revenue'].apply(revenue_simplifier)

# %%
df['Revenue'].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            204
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# Name: count, dtype: int64

# %%
df['Size'].value_counts()
# Out:
# Size
# 1001 to 5000 employees     150
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# Unknown                      9
# -1                           1
# Name: count, dtype: int64

# %%
# Cleaning Size column
def size_simplifier(text):
    if '-1' in text.lower():
        return 'Unknown'
    else:
        return text
    
df['Size'] = df['Size'].apply(size_simplifier)
# Out:
# C:\Users\Karma Soni\AppData\Local\Temp\ipykernel_21200\1798440598.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Size'] = df['Size'].apply(size_simplifier)

# %%
df['Size'].value_counts()
# Out:
# Size
# 1001 to 5000 employees     150
# 501 to 1000 employees      134
# 10000+ employees           130
# 201 to 500 employees       117
# 51 to 200 employees         94
# 5001 to 10000 employees     76
# 1 to 50 employees           31
# Unknown                     10
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (742, 28)

# %%
df.head(2)
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
#
#                             Company Name         Location   Headquarters  \
# 0                      Tecolote Research  Albuquerque, NM     Goleta, CA
# 1  University of Maryland Medical System    Linthicum, MD  Baltimore, MD
#
#                     Size  Founded   Type of ownership  ... average_salary  \
# 0  501 to 1000 employees     1973             Private  ...           72.0
# 1       10000+ employees     1984  Other Organization  ...           87.5
#
#   job_state company_age  python_job  r_job  spark_job  aws_job  excel_job  \
# 0        NM          50           1      0          0        0          1
# ...

# %% [markdown]
# # Data Analysis

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df.describe()
# Out:
#            Rating      Founded  Competitors  salary_per_hour  \
# count  742.000000   742.000000   742.000000       742.000000
# mean     3.618868  1837.154987     1.053908         0.032345
# std      0.801210   497.183763     1.384239         0.177034
# min     -1.000000    -1.000000     0.000000         0.000000
# 25%      3.300000  1939.000000     0.000000         0.000000
# 50%      3.700000  1988.000000     0.000000         0.000000
# 75%      4.000000  2007.000000     3.000000         0.000000
# max      5.000000  2019.000000     4.000000         1.000000
#
#        emp_provided_salary  min_salary  max_salary  average_salary  \
# count           742.000000  742.000000  742.000000      742.000000
# mean              0.022911   74.719677  128.149596      100.626011
# std               0.149721   30.980593   45.220324       38.855948
# min               0.000000   15.000000   16.000000       13.500000
# 25%               0.000000   52.000000   96.000000       73.500000
# ...

# %%
df['Rating'].hist()
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.title('Company Rating Histogram')
# Out:
# Text(0.5, 1.0, 'Company Rating Histogram')

# %%
df['company_age'].hist()
plt.xlabel('Time (in Years)')
plt.ylabel('Count')
plt.title('Cmpany Age Histogram')
# Out:
# Text(0.5, 1.0, 'Cmpany Age Histogram')

# %%
df['average_salary'].hist()
plt.xlabel('Annual Salary (in $)')
plt.ylabel('Count')
plt.title('Average Salary Histogram')
# Out:
# Text(0.5, 1.0, 'Average Salary Histogram')

# %%
# To see the outliers
sns.boxplot(y='average_salary', data=df, orient='v', palette='Set1')
# Out:
# <Axes: ylabel='average_salary'>

# %%
sns.boxplot(y='company_age', data=df, orient='v', palette='Set1')
# Out:
# <Axes: ylabel='company_age'>

# %%
sns.boxplot(y='Rating', data=df, orient='v', palette='Set1')
# Out:
# <Axes: ylabel='Rating'>

# %% [markdown]
# ### Pivot table

# %%
pd.pivot_table(df, index=['job_title_simplified', 'job_seniority'], values='average_salary')
# Out:
#                                     average_salary
# job_title_simplified job_seniority
# analyst              jr                  56.500000
#                      na                  61.155405
#                      senior              79.092593
# data engineer        na                  97.493976
#                      senior             123.638889
# data scientist       jr                 106.500000
#                      na                 110.525510
#                      senior             134.524390
# director             na                 168.607143
# manager              na                  84.022727
# mle                  na                 126.218750
#                      senior             127.000000
# na                   na                  76.885714
#                      senior             110.204545

# %%
pd.pivot_table(df, index=['job_state','job_title_simplified'], values='average_salary').sort_values('average_salary')
# Out:
#                                 average_salary
# job_state job_title_simplified
# TN        analyst                    13.500000
# LA        na                         20.000000
# DE        na                         27.500000
# CO        analyst                    29.500000
#           na                         31.500000
# ...                                        ...
# CA        data scientist            142.522059
# DC        data scientist            149.000000
# NJ        director                  161.500000
# CA        mle                       177.300000
# IL        director                  221.750000
#
# [114 rows x 1 columns]

# %%
pd.pivot_table(df, index='Industry', values='average_salary').sort_values('average_salary', ascending=False)
# Out:
#                                           average_salary
# Industry
# Other Retail Stores                           163.500000
# Motion Picture Production & Distribution      146.000000
# Financial Analytics & Research                145.125000
# Health, Beauty, & Fitness                     139.500000
# Telecommunications Services                   131.500000
# Brokerage Services                            129.000000
# Auctions & Galleries                          128.000000
# Internet                                      123.810345
# Investment Banking & Asset Management         118.400000
# TV Broadcast & Cable Networks                 117.750000
# Enterprise Software & Network Solutions       115.369048
# Computer Hardware & Software                  115.194915
# -1                                            114.650000
# Accounting                                    113.500000
# Biotech & Pharmaceuticals                     111.767857
# ...

# %%
pd.pivot_table(df, index='Sector', values='average_salary').sort_values('average_salary', ascending=False)
# Out:
#                                     average_salary
# Sector
# Media                                   116.666667
# -1                                      114.650000
# Accounting & Legal                      113.500000
# Information Technology                  113.191667
# Biotech & Pharmaceuticals               111.767857
# Insurance                               105.942029
# Real Estate                             104.750000
# Mining & Metals                         104.000000
# Telecommunications                      102.333333
# Education                               100.739130
# Consumer Services                        99.875000
# Retail                                   99.666667
# Transportation & Logistics               99.312500
# Aerospace & Defense                      99.060000
# Business Services                        97.701031
# Finance                                  97.369048
# Manufacturing                            84.044118
# ...

# %%
def sector_simplifier(text):
    if '-1' in text.lower():
        return 'Unknown / Non-Applicable'
    else:
        return text
    
df['Sector'] = df['Sector'].apply(sector_simplifier)

# %%
pd.pivot_table(df, index='Sector', values='average_salary').sort_values('average_salary', ascending=False)
# Out:
#                                     average_salary
# Sector
# Media                                   116.666667
# Unknown / Non-Applicable                114.650000
# Accounting & Legal                      113.500000
# Information Technology                  113.191667
# Biotech & Pharmaceuticals               111.767857
# Insurance                               105.942029
# Real Estate                             104.750000
# Mining & Metals                         104.000000
# Telecommunications                      102.333333
# Education                               100.739130
# Consumer Services                        99.875000
# Retail                                   99.666667
# Transportation & Logistics               99.312500
# Aerospace & Defense                      99.060000
# Business Services                        97.701031
# Finance                                  97.369048
# Manufacturing                            84.044118
# ...

# %%
# Type of Companies that pay Data Scientists well
pd.pivot_table(df, index='Type of ownership', values='average_salary').sort_values('average_salary', ascending=False)[:10]
# Out:
#                                 average_salary
# Type of ownership
# Public                              110.893782
# Subsidiary or Business Segment      110.573529
# College / University                107.615385
# Private                             101.776829
# Government                           84.300000
# Other Organization                   77.900000
# School / School District             77.750000
# Nonprofit Organization               68.281818
# Hospital                             54.000000

# %%
# Top Companies that pay data scientists well
pd.pivot_table(df, index='Company Name', values='average_salary').sort_values('average_salary', ascending=False)[:10]
# Out:
#                           average_salary
# Company Name
# Gallup                             237.5
# Sage Intacct                       232.5
# CA-One Tech Cloud                  225.0
# Grand Rounds                       221.5
# Credit Sesame                      205.0
# The Climate Corporation            194.0
# Grainger                           179.5
# Samsung Research America           177.0
# Nektar Therapeutics                174.0
# DTCC                               173.0

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Trimming Columns

# %%
industry_list = ['Aerospace & Defense', 'Health Care Services & Hospitals', 'Advertising & Marketing', 'Consulting', 'Internet', 'Biotech & Pharmaceuticals', 'Enterprise Software & Network Solutions', 'Insurance Carriers', 'IT Services',
       'Computer Hardware & Software', 'Consumer Products Manufacturing']

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# -1                                           10
# Staffing & Outsourcing                       10
# Travel Agencies                               8
# ...

# %%
def industry_simplifier(text):
    if '-1' in text.lower():
        return 'Others'
    else:
        return text
    
df['Industry'] = df['Industry'].apply(industry_simplifier)

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Biotech & Pharmaceuticals                   112
# Insurance Carriers                           63
# Computer Hardware & Software                 59
# IT Services                                  50
# Health Care Services & Hospitals             49
# Enterprise Software & Network Solutions      42
# Internet                                     29
# Consulting                                   29
# Aerospace & Defense                          25
# Advertising & Marketing                      25
# Consumer Products Manufacturing              20
# Research & Development                       19
# Colleges & Universities                      16
# Energy                                       14
# Others                                       14
# Banks & Credit Unions                        12
# Federal Agencies                             11
# Staffing & Outsourcing                       10
# Travel Agencies                               8
# ...

# %%
industry_list = ['Aerospace & Defense', 'Health Care Services & Hospitals', 'Advertising & Marketing', 'Consulting', 'Internet', 'Biotech & Pharmaceuticals', 'Enterprise Software & Network Solutions', 'Insurance Carriers', 'IT Services',
       'Computer Hardware & Software', 'Consumer Products Manufacturing', 'Others']

def industry_simplifier(text):
    if text not in industry_list:
        return 'Others'
    else:
        return text
    
df['Industry'] = df['Industry'].apply(industry_simplifier)

# %%
df['Industry'].value_counts()
# Out:
# Industry
# Others                                     239
# Biotech & Pharmaceuticals                  112
# Insurance Carriers                          63
# Computer Hardware & Software                59
# IT Services                                 50
# Health Care Services & Hospitals            49
# Enterprise Software & Network Solutions     42
# Consulting                                  29
# Internet                                    29
# Aerospace & Defense                         25
# Advertising & Marketing                     25
# Consumer Products Manufacturing             20
# Name: count, dtype: int64

# %%
# Trimming the job state column:
job_state_list = ['CA', 'MA', 'NY', 'VA', 'IL', 'MD', 'PA', 'TX', 'NC', 'WA']

def job_state_simplifier(text):
    if text not in job_state_list:
        return 'Others'
    else:
        return text

df['job_state'] = df['job_state'].apply(job_state_simplifier)

# %%
df['job_state'].value_counts()
# Out:
# job_state
# Others    196
# CA        152
# MA        103
# NY         72
# VA         41
# IL         40
# MD         35
# PA         33
# TX         28
# WA         21
# NC         21
# Name: count, dtype: int64

# %%
df['job_in_headquarters'] = df.apply(lambda x: 1 if x['Location'] == x['Headquarters'] else 0, axis = 1)

# %%
df['job_in_headquarters'].value_counts()
# Out:
# job_in_headquarters
# 1    414
# 0    328
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'salary_per_hour', 'emp_provided_salary', 'min_salary', 'max_salary',
#        'average_salary', 'job_state', 'company_age', 'python_job', 'r_job',
#        'spark_job', 'aws_job', 'excel_job', 'job_title_simplified',
#        'job_seniority', 'job_in_headquarters'],
#       dtype='object')

# %% [markdown]
# ## Choosing only the relevant Columns

# %%
df_model = df.copy(deep=True)
df_model = df_model[['average_salary', 'Rating','company_age', 'Size', 'Type of ownership','Industry','Revenue','Competitors', 'job_title_simplified', 'job_seniority', 'job_state', 'job_in_headquarters', 'python_job', 'spark_job', 'aws_job', 'excel_job']]

# %%
df_model.rename(columns={'Rating': 'company_rating', 'Size': 'company_size', 'Type of ownership':'type_of_ownership', 'Industry': 'industry', 'Revenue':'revenue', 'Competitors': 'competitors'}, inplace=True)

# %%
df_model.columns
# Out:
# Index(['average_salary', 'company_rating', 'company_age', 'company_size',
#        'type_of_ownership', 'industry', 'revenue', 'competitors',
#        'job_title_simplified', 'job_seniority', 'job_state',
#        'job_in_headquarters', 'python_job', 'spark_job', 'aws_job',
#        'excel_job'],
#       dtype='object')

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age            company_size  \
# 0            72.0             3.8           50   501 to 1000 employees
# 1            87.5             3.4           39        10000+ employees
# 2            85.0             4.8           13   501 to 1000 employees
# 3            76.5             3.8           58  1001 to 5000 employees
# 4           114.5             2.9           25     51 to 200 employees
#
#     type_of_ownership                          industry  \
# 0             Private               Aerospace & Defense
# 1  Other Organization  Health Care Services & Hospitals
# 2             Private                            Others
# 3          Government                            Others
# 4             Private           Advertising & Marketing
#
#                             revenue  competitors job_title_simplified  \
# 0         $50 to $100 million (USD)            0       data scientist
# ...

# %% [markdown]
# ## Ordinal Categories (having mathematical meanings)

# %%
# Giving ranks to 'company_size'
size_map = {'Unknown': 0, '1 to 50 employees': 1, '51 to 200 employees': 2, '201 t0 500 employees': 3, '501 to 1000 employees': 4, '1001 to 5000 employees': 5, '5001 to 10000 employees': 6, '10000+ employees': 7}

# %%
df_model['company_size_rank'] = df_model['company_size'].map(size_map)
df_model.drop('company_size', axis=True, inplace=True)

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age   type_of_ownership  \
# 0            72.0             3.8           50             Private
# 1            87.5             3.4           39  Other Organization
# 2            85.0             4.8           13             Private
# 3            76.5             3.8           58          Government
# 4           114.5             2.9           25             Private
#
#                            industry                           revenue  \
# 0               Aerospace & Defense         $50 to $100 million (USD)
# 1  Health Care Services & Hospitals            $2 to $5 billion (USD)
# 2                            Others        $100 to $500 million (USD)
# 3                            Others  $500 million to $1 billion (USD)
# 4           Advertising & Marketing          Unknown / Non-Applicable
#
#    competitors job_title_simplified job_seniority job_state  \
# 0            0       data scientist            na    Others
# ...

# %%
# Mapping ranks to 'revenue columns' as well
df['Revenue'].value_counts()
# Out:
# Revenue
# Unknown / Non-Applicable            204
# $10+ billion (USD)                  124
# $100 to $500 million (USD)           91
# $1 to $2 billion (USD)               60
# $500 million to $1 billion (USD)     57
# $50 to $100 million (USD)            46
# $25 to $50 million (USD)             40
# $2 to $5 billion (USD)               39
# $10 to $25 million (USD)             32
# $5 to $10 billion (USD)              19
# $5 to $10 million (USD)              18
# $1 to $5 million (USD)                8
# Less than $1 million (USD)            4
# Name: count, dtype: int64

# %%
revenue_map = {'Unknown / Non-Applicable': 0, 'Less than $1 million (USD)': 1, '$1 to $5 million (USD)': 2, '$5 to $10 million (USD)': 3, '$10 to $25 million (USD)': 4, '$25 to $50 million (USD)': 5, '$50 to $100 million (USD)': 6, '$100 to $500 million (USD)': 7, '$500 million to $1 billion (USD)': 8, "$1 to $2 billion (USD)": 9, '$2 to $5 billion (USD)': 10, '$5 to $10 billion (USD)': 11, '$10+ billion (USD)': 12}

df_model['company_revenue_rank'] = df_model['revenue'].map(revenue_map)
df_model.drop('revenue', axis=True, inplace=True)

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age   type_of_ownership  \
# 0            72.0             3.8           50             Private
# 1            87.5             3.4           39  Other Organization
# 2            85.0             4.8           13             Private
# 3            76.5             3.8           58          Government
# 4           114.5             2.9           25             Private
#
#                            industry  competitors job_title_simplified  \
# 0               Aerospace & Defense            0       data scientist
# 1  Health Care Services & Hospitals            0       data scientist
# 2                            Others            0       data scientist
# 3                            Others            3       data scientist
# 4           Advertising & Marketing            3       data scientist
#
#   job_seniority job_state  job_in_headquarters  python_job  spark_job  \
# ...

# %%
# Mapping ranks to 'job seniority' 
df_model['job_seniority'].value_counts()
# Out:
# job_seniority
# na        545
# senior    195
# jr          2
# Name: count, dtype: int64

# %%
job_seniority_map = {'na': 0, 'jr': 1, 'senior': 2}

df_model['job_seniority_rank'] = df_model['job_seniority'].map(job_seniority_map)
df_model.drop('job_seniority', axis=True, inplace=True)

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age   type_of_ownership  \
# 0            72.0             3.8           50             Private
# 1            87.5             3.4           39  Other Organization
# 2            85.0             4.8           13             Private
# 3            76.5             3.8           58          Government
# 4           114.5             2.9           25             Private
#
#                            industry  competitors job_title_simplified  \
# 0               Aerospace & Defense            0       data scientist
# 1  Health Care Services & Hospitals            0       data scientist
# 2                            Others            0       data scientist
# 3                            Others            3       data scientist
# 4           Advertising & Marketing            3       data scientist
#
#   job_state  job_in_headquarters  python_job  spark_job  aws_job  excel_job  \
# ...

# %%
df_model['job_seniority_rank'].value_counts()
# Out:
# job_seniority_rank
# 0    545
# 2    195
# 1      2
# Name: count, dtype: int64

# %%
df_model.columns
# Out:
# Index(['average_salary', 'company_rating', 'company_age', 'type_of_ownership',
#        'industry', 'competitors', 'job_title_simplified', 'job_state',
#        'job_in_headquarters', 'python_job', 'spark_job', 'aws_job',
#        'excel_job', 'company_size_rank', 'company_revenue_rank',
#        'job_seniority_rank'],
#       dtype='object')

# %% [markdown]
# ## Handling Nominal Categorical Features (No mathematical meaning)

# %%
df_model.shape
# Out:
# (742, 16)

# %%
df_model = pd.get_dummies(columns=['type_of_ownership'], data=df_model)
df_model.shape
# Out:
# (742, 24)

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age  \
# 0            72.0             3.8           50
# 1            87.5             3.4           39
# 2            85.0             4.8           13
# 3            76.5             3.8           58
# 4           114.5             2.9           25
#
#                            industry  competitors job_title_simplified  \
# 0               Aerospace & Defense            0       data scientist
# 1  Health Care Services & Hospitals            0       data scientist
# 2                            Others            0       data scientist
# 3                            Others            3       data scientist
# 4           Advertising & Marketing            3       data scientist
#
#   job_state  job_in_headquarters  python_job  spark_job  ...  \
# 0    Others                    0           1          0  ...
# 1        MD                    0           1          0  ...
# 2    Others                    1           1          1  ...
# ...

# %%
df_model = pd.get_dummies(columns=['industry'], data=df_model)
df_model.shape
# Out:
# (742, 35)

# %%
df_model = pd.get_dummies(columns=['job_title_simplified'], data=df_model)
df_model.shape
# Out:
# (742, 41)

# %%
df_model = pd.get_dummies(columns=['job_state'], data=df_model)
df_model.shape
# Out:
# (742, 51)

# %% [markdown]
# ## Feature Scaling

# %%
df_model.head()
# Out:
#    average_salary  company_rating  company_age  competitors  \
# 0            72.0             3.8           50            0
# 1            87.5             3.4           39            0
# 2            85.0             4.8           13            0
# 3            76.5             3.8           58            3
# 4           114.5             2.9           25            3
#
#    job_in_headquarters  python_job  spark_job  aws_job  excel_job  \
# 0                    0           1          0        0          1
# 1                    0           1          0        0          0
# 2                    1           1          1        0          1
# 3                    1           1          0        0          0
# 4                    1           1          0        0          1
#
#    company_size_rank  ...  job_state_IL  job_state_MA  job_state_MD  \
# 0                4.0  ...         False         False         False
# ...

# %%
df_model.isnull().sum()
# Out:
# average_salary                                        0
# company_rating                                        0
# company_age                                           0
# competitors                                           0
# job_in_headquarters                                   0
# python_job                                            0
# spark_job                                             0
# aws_job                                               0
# excel_job                                             0
# company_size_rank                                   117
# company_revenue_rank                                  0
# job_seniority_rank                                    0
# type_of_ownership_College / University                0
# type_of_ownership_Government                          0
# type_of_ownership_Hospital                            0
# type_of_ownership_Nonprofit Organization              0
# type_of_ownership_Other Organization                  0
# ...

# %%
df_model.dropna(inplace=True)

# %%
df_model.shape
# Out:
# (625, 51)

# %% [markdown]
# # Machine Learning Algo Implementation

# %%
X = df_model.drop('average_salary', axis=1)
y = df_model['average_salary']

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
columns_to_scale = ['company_rating', 'competitors', 'company_age', 'company_size_rank', 'company_revenue_rank']
X[columns_to_scale] = scaler.fit_transform(X[columns_to_scale])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)
print("Training set size: {} and Testing set size: {}".format(X_train.shape, X_test.shape))
# Out:
# Training set size: (500, 50) and Testing set size: (125, 50)

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr_model = LinearRegression()

# %%
lr_model.fit(X_train, y_train)
print("Accuracy of Linear Regression Model on Training set is : {} % and on Test set is {} %".format(round(lr_model.score(X_train, y_train),4)*100, round(lr_model.score(X_test, y_test), 4)*100))
# Out:
# Accuracy of Linear Regression Model on Training set is : 56.489999999999995 % and on Test set is 52.580000000000005 %

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor
decision_model = DecisionTreeRegressor(criterion='friedman_mse', max_depth=11, random_state=42)

# %%
decision_model.fit(X_train, y_train)
print("Accuracy of Decision Tree Regression Model on Training set is : {} % and on Test set is {} %".format(round(decision_model.score(X_train, y_train),4)*100, round(decision_model.score(X_test, y_test), 4)*100))
# Out:
# Accuracy of Decision Tree Regression Model on Training set is : 95.97 % and on Test set is 66.34 %

# %%
y_test
# Out:
# 688    122.5
# 736    100.0
# 331    225.0
# 326     63.5
# 730     91.5
#        ...
# 208    225.0
# 871    194.0
# 349     96.0
# 633     52.5
# 285     84.0
# Name: average_salary, Length: 125, dtype: float64

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.ensemble import RandomForestRegressor
forest_model = RandomForestRegressor(n_estimators=100, criterion='friedman_mse', random_state=42)

# %%
forest_model.fit(X_train, y_train)
print("Accuracy of Random Forest Regression Model on Training set is : {} % and on Test set is {} %".format(round(forest_model.score(X_train, y_train),4)*100, round(forest_model.score(X_test, y_test), 4)*100))
# Out:
# Accuracy of Random Forest Regression Model on Training set is : 94.73 % and on Test set is 67.77 %

# %% [markdown]
# ### AdaBoost Regression Model

# %%
from sklearn.ensemble import AdaBoostRegressor
adb_model = AdaBoostRegressor(base_estimator=decision_model, n_estimators=250, learning_rate=1, random_state=42)

# %%
adb_model.fit(X_train, y_train)
print("Accuracy of AdaBoost Regression Model on Training set is : {} % and on Test set is {} %".format(round(adb_model.score(X_train, y_train),4)*100, round(adb_model.score(X_test, y_test), 4)*100))
# Out:
# Accuracy of AdaBoost Regression Model on Training set is : 95.05 % and on Test set is 67.86 %
